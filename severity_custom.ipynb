# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets,transforms
from torch.utils.data import DataLoader

# %%
# check device GPU or CPU
if torch.cuda.is_available():
    device=torch.device="cuda"
else:
    device=torch.device="cpu"

print(f"Using device: {device}")
# Out:
# Using device: cpu

# %%
# Configuration (img_size, transform and normalize)
# Global Parameters
DATADIR='Modal_img'
IMG_SIZE=128
BATCH_SIZE=32
SEED=42
EPOCHS=50

# Calculation of mean and standard deviation of the dataset
# Transform
calc_transform=transforms.Compose([
    transforms.Resize((128,128)),
    transforms.ToTensor()
])

# Load full dataset for calculation purpose
calc_dataset=datasets.ImageFolder(DATADIR,transform=calc_transform)
calc_loader=DataLoader(calc_dataset, batch_size=64, shuffle=False)

# Calculate mean and standard deviation
mean=0
std=0
total_samples=0

for images, _ in calc_loader:
    batch_samples=images.size(0)
    images=images.view(batch_samples, images.size(1), -1)
    mean += images.mean(2).sum(0)
    std += images.std(2).sum(0)
    total_samples += batch_samples

final_mean=mean/total_samples
final_std=std/total_samples

# DEBUG: Mean and Standard Deviation
print("\n=== Results for mean and std: ===")
print(f"Dataset Mean (R, B, G): {final_mean.tolist()}")
print(f"Dataset Standard Deviation (R, B, G): {final_std.tolist()}")

FINAL_MEAN=final_mean.tolist()
FINAL_STD=final_std.tolist()

train_transform = transforms.Compose([
    transforms.RandomResizedCrop(IMG_SIZE, scale=(0.7, 1.0), ratio=(0.75, 1.333)),
    
    # 2. Geometric Variations
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(45), 
    transforms.RandomAffine(degrees=0, shear=15, translate=(0.1, 0.1)), 
    
    transforms.ColorJitter(brightness=0.4, contrast=0.4, saturation=0.4, hue=0.1), 
    
    transforms.ToTensor(),
    transforms.RandomErasing(p=0.5, scale=(0.02, 0.33), ratio=(0.3, 3.3)), 
    
    # 5. Normalization
    transforms.Normalize(FINAL_MEAN, FINAL_STD)
])
val_test_transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)), 
    transforms.ToTensor(),
    transforms.Normalize(mean=FINAL_MEAN, std=FINAL_STD)
])

# Load full dataset
full_dataset=datasets.ImageFolder(DATADIR,transform=train_transform)

CLASS_NAMES=full_dataset.classes
NUM_CLASSES=len(CLASS_NAMES)

# DEBUG: check whether all classes exists
REQUIRED_CLASSES=['no accident','minor','intermediate','major']
if not all (c in CLASS_NAMES for c in REQUIRED_CLASSES):
    raise ValueError(f"Dataset missing required folders. Found: {CLASS_NAMES}")
NO_ACCIDENT_IDX=CLASS_NAMES.index('no accident')

# DEBUG: Class Name and Total image loaded
print("\n=== Results for class name and total amount of images: ===")
print(f"Number of classes: {NUM_CLASSES}")
print(f"Class Names: {CLASS_NAMES}")
print(f"Total amount of images: {len(full_dataset)}")
# Out:
# === Results for mean and std: ===
# Dataset Mean (R, B, G): [0.46021583676338196, 0.4511672258377075, 0.45412397384643555]
# Dataset Standard Deviation (R, B, G): [0.24809545278549194, 0.2457689493894577, 0.2474203258752823]
#
# === Results for class name and total amount of images: ===
# Number of classes: 4
# Class Names: ['intermediate', 'major', 'minor', 'no accident']
# Total amount of images: 1791

# %%
from model_definitions import CNNModel

# %%
from sklearn.metrics import f1_score, confusion_matrix, roc_auc_score
from sklearn.preprocessing import label_binarize
import torch.nn.functional as F
import os
import numpy as np
import time

# The usable training function
def train_cnn(model,train_loader,val_loader,num_classes, model_name, num_epochs,learning_rate, class_weights=None):
    model_dir = "models"
    os.makedirs(model_dir, exist_ok=True)
    model_save_path = os.path.join(model_dir, f"{model_name.lower().replace(' ','_')}_cnn_pytorch.pth")
    # Early Stopping Configuration
    PATIENCE=8
    best_f1=0.0
    epochs_no_improve=0
    
    # Reduce LR On Plateau
    LR_FACTOR=0.5
    LR_PATIENCE=4
    lr_epochs_no_improve=0
    
    # Define loss function
    if class_weights is not None:
        criterion=nn.CrossEntropyLoss(weight=class_weights)
        print(f"  (Using Weighted Loss: {class_weights.tolist()})")
    else:
        criterion=nn.CrossEntropyLoss()
    # Define Optimizer
    optimizer=optim.Adam(model.parameters(),lr=learning_rate)

    train_losses=[]
    val_losses=[]
    val_accuracies=[]
    train_accuracies=[]
    val_f1_scores=[]
    val_auc_scores=[]

    # LOG: Display Model Training Process
    print(f"\n=== Starting CNN Model Training for {model_name} (Classes: {num_classes}):===\n")
    print(f"    (Epochs: {num_epochs}, Learning Rate: {learning_rate})")

    for epoch in range(num_epochs):
        start_time=time.time()
        # Training phase (Training mode)
        model.train()
        running_loss=0.0
        correct_train, total_train =0,0
        for inputs,labels in train_loader:
            inputs,labels=inputs.to(device),labels.to(device)
            
            optimizer.zero_grad()
            # forward pass
            outputs=model(inputs)
            loss=criterion(outputs,labels)
            # backward pass to calc gradient
            loss.backward()
            optimizer.step()
            
            running_loss+=loss.item()
            _,predicted=torch.max(outputs.data,1)
            total_train += labels.size(0)
            correct_train += (predicted == labels).sum().item()
            
        avg_train_loss=running_loss/len(train_loader)
        train_accuracy=100*correct_train/total_train
        train_losses.append(avg_train_loss)
        train_accuracies.append(train_accuracy)

        
        # Validation Phase (Evaluation mode)
        model.eval()
        all_labels=[]
        all_predictions=[]
        all_scores=[]
        correct=0
        total=0
        val_running_loss=0.0
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels=inputs.to(device), labels.to(device)
                outputs=model(inputs)
                val_loss = criterion(outputs, labels)
                val_running_loss += val_loss.item()
                # Get the logits
                all_scores.extend(outputs.cpu().numpy())
                _,predicted=torch.max(outputs.data,1)
                
                # Collected labels and predictions
                all_labels.extend(labels.cpu().numpy())
                all_predictions.extend(predicted.cpu().numpy())
                
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
            
        val_accuracy =100*correct/total
        val_accuracies.append(val_accuracy)
        avg_val_loss = val_running_loss / len(val_loader)
        val_losses.append(avg_val_loss)
        
        # F1 score
        macro_f1=f1_score(all_labels, all_predictions,average="macro",zero_division=0)
        val_f1_scores.append(macro_f1)
        
        # AUC scores
        softmax_scores = F.softmax(torch.tensor(all_scores), dim=1).numpy()
        
        try:
            if num_classes > 2:
                # 2. MULTI-CLASS (OVR) CLASSIFICATION LOGIC
                # y_true must be 2D one-hot encoded (y_true_bin).
                # y_score must be 2D softmax scores.
                y_true_bin = label_binarize(all_labels, classes=range(num_classes))
                macro_auc = roc_auc_score(y_true_bin, softmax_scores, average="macro", multi_class='ovr')
                
            else:
                macro_auc = 0.0 
                
        except ValueError as e:
            macro_auc = 0.0 
            print(f"Error: Could not compute AUC. {e}")
        
        val_auc_scores.append(macro_auc)
        
        # Confusion Matrix
        confusion=confusion_matrix(all_labels, all_predictions)
        
        end_time=time.time()
        epoch_time=end_time-start_time
    
        # LOG: Display results for each epoch
        print(f"[Epoch {epoch+1:03}/{num_epochs}] " 
              f"Train Loss: {avg_train_loss:.4f} | "
              f"Train Acc: {train_accuracy:.2f}% | "
              f"Val Acc: {val_accuracy:.2f}% | "
              f"Val F1: {macro_f1:.4f} | "
              f"Val AUC: {macro_auc:.4f} | "
              f"Time: {epoch_time:.2f}s")
        
        # Model Checkpoint
        if macro_f1 > best_f1:
            best_f1=macro_f1
            epochs_no_improve=0
            lr_epochs_no_improve=0
            torch.save(model.state_dict(), model_save_path)
            print(f"\n{model_name} Model weights successfully saved to: {model_save_path}")
            best_confusion=confusion
            best_all_labels=all_labels
            best_all_predictions=all_predictions
            best_softmax_scores=softmax_scores
        else:
            epochs_no_improve +=1
            lr_epochs_no_improve+=1
            
            # Early stopping
            if epochs_no_improve >= PATIENCE:
                print(f"\n! EARLY STOPPING triggered at epoch {epoch+1}. Validation F1 score has not improved for {PATIENCE} epochs.")
                break
            
            # Reduce LR on PlateEU
            if lr_epochs_no_improve >= LR_PATIENCE:
                old_lr=optimizer.param_groups[0]['lr']
                new_lr=old_lr * LR_FACTOR
                if new_lr < 1e-6:
                    new_lr=1e-6
                if new_lr<old_lr:
                    optimizer.param_groups[0]['lr']=new_lr
                    print(f"\n ReduceLROnPlateau: Reducing learning rate from {old_lr:.6f} to {new_lr:.6f}")
                    lr_epochs_no_improve = 0 
                    
        if torch.cuda.is_available():
            torch.cuda.empty_cache()
        
    print("\n== Training Done ==")
    
    if os.path.exists(model_save_path):
        model.load_state_dict(torch.load(model_save_path))
        print(f"\nFinal: Loaded best model weights (F1: {best_f1:.4f}) from {model_save_path}")
        
    return model,train_losses,val_accuracies,macro_f1,best_confusion,best_all_labels,best_all_predictions,best_softmax_scores,train_accuracies,val_losses

# %%
from torch.utils.data import WeightedRandomSampler
from sklearn.model_selection import StratifiedShuffleSplit
from torch.utils.data import Subset
# Global Parameter for two-stage training
INITIAL_LR=0.0001
FINE_TUNE_LR=0.00001

# Model B: Severity Classifier (Accident Image Only)
print("\n=== Starting Model B: Severity Classifier ===\n")

# Get for accident images only
accident_class_indices=[]
for i, (path,label_index) in enumerate(full_dataset.imgs):
    if(label_index != NO_ACCIDENT_IDX):
        accident_class_indices.append(i)

severity_dataset_subset=Subset(full_dataset,accident_class_indices)
ACCIDENT_CLASSES=[]
for name in CLASS_NAMES:
    if name != "no accident":
        ACCIDENT_CLASSES.append(name)

SEVERITY_NUM_CLASSES=len(ACCIDENT_CLASSES)

# DEBUG: show number of severity classes being trained
print(f"Severity classes being trained: {ACCIDENT_CLASSES}")

# Split data (80:20) 
all_severity_labels = [full_dataset.targets[i] for i in severity_dataset_subset.indices]
unique_accident_labels = sorted(np.unique(all_severity_labels))
label_map = {original_label: new_label for new_label, original_label in enumerate(unique_accident_labels)}
stratify_labels = np.array([label_map[orig_label] for orig_label in all_severity_labels])
sss = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=SEED) 
for train_index, val_index in sss.split(severity_dataset_subset.indices, stratify_labels):
    severity_train_indices = train_index
    severity_val_indices = val_index

severity_train_dataset = Subset(severity_dataset_subset, severity_train_indices)
severity_val_dataset = Subset(severity_dataset_subset, severity_val_indices)

# Implement Weighted Random Sampler
original_accident_labels = [full_dataset.targets[i] for i in severity_train_dataset.indices]
all_original_labels = np.array(full_dataset.targets)
unique_accident_labels = sorted(np.unique(original_accident_labels))  

train_targets = np.array([label_map[orig_label] for orig_label in original_accident_labels])
class_counts=np.bincount(train_targets)
num_severity_classes = len(ACCIDENT_CLASSES)
if len(class_counts) == num_severity_classes:
    print(f"\n=== Training Set Imbalance Check (Severity):===")
    for i, count in enumerate(class_counts):
        print(f"{ACCIDENT_CLASSES[i]} (Class {i}) Samples: {count}")
    
    weights_per_class=1. / class_counts
    sample_weights=[weights_per_class[target] for target in train_targets]

    sampler=WeightedRandomSampler(
        weights=sample_weights,
        num_samples=len(sample_weights),
        replacement=True
    )

    severity_train_loader=DataLoader(severity_train_dataset, batch_size=BATCH_SIZE, sampler=sampler)
else:
    print("Warning: Incorrect number of severity classes found in training data.")
    # Fallback to simple shuffling if sampler cannot be built
    severity_train_loader=DataLoader(severity_train_dataset, batch_size=BATCH_SIZE, shuffle=True)

severity_val_loader=DataLoader(severity_val_dataset, batch_size=BATCH_SIZE, shuffle=False)

# Start to train
severity_model=CNNModel(SEVERITY_NUM_CLASSES).to(device)
# Stage 1: Initial Training (High Learning Rate)
print(f"\n=== STARTING SEVERITY MODEL INITIAL TRAINING ({EPOCHS} EPOCHS and Higher Learning rate) ===")
severity_model, _, _,_,_,_,_,_,_,_=train_cnn(severity_model,severity_train_loader,severity_val_loader,SEVERITY_NUM_CLASSES,"Severity_Custom_Initial", num_epochs=EPOCHS, learning_rate=INITIAL_LR)
# Stage 2: Fine tuning (Low Learning Rate)
print(f"\n=== STARTING SEVERITY MODEL FINE-TUNING ({EPOCHS} EPOCHS and Lower Learning rate) ===")
severity_model, severity_losses, severity_accuracies,severity_f1_score,severity_cm,severity_labels,severity_predictions, severity_auc,train_accuracies,val_losses=train_cnn(severity_model,severity_train_loader,severity_val_loader,SEVERITY_NUM_CLASSES,"Severity_Custom_Final", num_epochs=EPOCHS, learning_rate=FINE_TUNE_LR)
# Out:
# === Starting Model B: Severity Classifier ===
#
# Severity classes being trained: ['intermediate', 'major', 'minor']
#
# === Training Set Imbalance Check (Severity):===
# intermediate (Class 0) Samples: 370
# major (Class 1) Samples: 374
# minor (Class 2) Samples: 362
#
# === STARTING SEVERITY MODEL INITIAL TRAINING (50 EPOCHS and Higher Learning rate) ===
#
# === Starting CNN Model Training for Severity_Custom_Initial (Classes: 3):===
#
#     (Epochs: 50, Learning Rate: 0.0001)
# C:\Users\USER\AppData\Local\Temp\ipykernel_35216\1133255913.py:106: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\cb\pytorch_1000000000000\work\torch\csrc\utils\tensor_new.cpp:281.)
#   softmax_scores = F.softmax(torch.tensor(all_scores), dim=1).numpy()
# [Epoch 001/50] Train Loss: 1.4369 | Train Acc: 37.79% | Val Acc: 45.13% | Val F1: 0.3772 | Val AUC: 0.6321 | Time: 10.91s
#
# Severity_Custom_Initial Model weights successfully saved to: models\severity_custom_initial_cnn_pytorch.pth
# [Epoch 002/50] Train Loss: 1.0699 | Train Acc: 40.24% | Val Acc: 49.10% | Val F1: 0.3958 | Val AUC: 0.6817 | Time: 10.81s
#
# Severity_Custom_Initial Model weights successfully saved to: models\severity_custom_initial_cnn_pytorch.pth
# [Epoch 003/50] Train Loss: 1.0260 | Train Acc: 46.75% | Val Acc: 46.21% | Val F1: 0.4255 | Val AUC: 0.6776 | Time: 10.81s
#
# Severity_Custom_Initial Model weights successfully saved to: models\severity_custom_initial_cnn_pytorch.pth
# [Epoch 004/50] Train Loss: 1.0213 | Train Acc: 45.12% | Val Acc: 46.21% | Val F1: 0.4580 | Val AUC: 0.6720 | Time: 10.90s
#
# Severity_Custom_Initial Model weights successfully saved to: models\severity_custom_initial_cnn_pytorch.pth
# [Epoch 005/50] Train Loss: 1.0176 | Train Acc: 47.56% | Val Acc: 51.26% | Val F1: 0.4274 | Val AUC: 0.7069 | Time: 10.77s
# [Epoch 006/50] Train Loss: 1.0022 | Train Acc: 48.55% | Val Acc: 48.74% | Val F1: 0.4410 | Val AUC: 0.7004 | Time: 10.70s
# [Epoch 007/50] Train Loss: 0.9814 | Train Acc: 50.36% | Val Acc: 51.99% | Val F1: 0.5066 | Val AUC: 0.7072 | Time: 10.64s
#
# Severity_Custom_Initial Model weights successfully saved to: models\severity_custom_initial_cnn_pytorch.pth
# [Epoch 008/50] Train Loss: 1.0197 | Train Acc: 45.75% | Val Acc: 49.82% | Val F1: 0.4276 | Val AUC: 0.7195 | Time: 10.85s
# [Epoch 009/50] Train Loss: 0.9948 | Train Acc: 49.37% | Val Acc: 54.87% | Val F1: 0.5268 | Val AUC: 0.7261 | Time: 10.73s
#
# Severity_Custom_Initial Model weights successfully saved to: models\severity_custom_initial_cnn_pytorch.pth
# [Epoch 010/50] Train Loss: 0.9830 | Train Acc: 47.11% | Val Acc: 50.54% | Val F1: 0.5109 | Val AUC: 0.7217 | Time: 10.69s
# [Epoch 011/50] Train Loss: 1.0141 | Train Acc: 45.12% | Val Acc: 46.93% | Val F1: 0.4534 | Val AUC: 0.6788 | Time: 10.61s
# [Epoch 012/50] Train Loss: 0.9806 | Train Acc: 51.08% | Val Acc: 51.62% | Val F1: 0.4242 | Val AUC: 0.7261 | Time: 10.61s
# [Epoch 013/50] Train Loss: 0.9786 | Train Acc: 49.19% | Val Acc: 53.43% | Val F1: 0.4509 | Val AUC: 0.7082 | Time: 10.62s
#
#  ReduceLROnPlateau: Reducing learning rate from 0.000100 to 0.000050
# [Epoch 014/50] Train Loss: 0.9736 | Train Acc: 51.18% | Val Acc: 54.87% | Val F1: 0.5159 | Val AUC: 0.7253 | Time: 10.65s
# [Epoch 015/50] Train Loss: 0.9864 | Train Acc: 50.27% | Val Acc: 53.07% | Val F1: 0.5088 | Val AUC: 0.7102 | Time: 10.56s
# [Epoch 016/50] Train Loss: 1.0010 | Train Acc: 49.55% | Val Acc: 50.18% | Val F1: 0.4177 | Val AUC: 0.6952 | Time: 10.57s
# [Epoch 017/50] Train Loss: 0.9900 | Train Acc: 49.82% | Val Acc: 51.62% | Val F1: 0.5045 | Val AUC: 0.7428 | Time: 10.58s
#
# ! EARLY STOPPING triggered at epoch 17. Validation F1 score has not improved for 8 epochs.
#
# == Training Done ==
#
# Final: Loaded best model weights (F1: 0.5268) from models\severity_custom_initial_cnn_pytorch.pth
#
# === STARTING SEVERITY MODEL FINE-TUNING (50 EPOCHS and Lower Learning rate) ===
#
# === Starting CNN Model Training for Severity_Custom_Final (Classes: 3):===
#
#     (Epochs: 50, Learning Rate: 1e-05)
# C:\Users\USER\AppData\Local\Temp\ipykernel_35216\1133255913.py:177: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_save_path))
# [Epoch 001/50] Train Loss: 1.0089 | Train Acc: 48.55% | Val Acc: 49.46% | Val F1: 0.4889 | Val AUC: 0.6861 | Time: 10.70s
#
# Severity_Custom_Final Model weights successfully saved to: models\severity_custom_final_cnn_pytorch.pth
# [Epoch 002/50] Train Loss: 0.9813 | Train Acc: 48.82% | Val Acc: 48.74% | Val F1: 0.4441 | Val AUC: 0.7062 | Time: 10.70s
# [Epoch 003/50] Train Loss: 0.9459 | Train Acc: 53.35% | Val Acc: 53.79% | Val F1: 0.5049 | Val AUC: 0.6895 | Time: 10.67s
#
# Severity_Custom_Final Model weights successfully saved to: models\severity_custom_final_cnn_pytorch.pth
# [Epoch 004/50] Train Loss: 0.9790 | Train Acc: 50.54% | Val Acc: 51.99% | Val F1: 0.4929 | Val AUC: 0.7109 | Time: 10.75s
# [Epoch 005/50] Train Loss: 0.9962 | Train Acc: 50.63% | Val Acc: 51.26% | Val F1: 0.4807 | Val AUC: 0.7112 | Time: 10.72s
# [Epoch 006/50] Train Loss: 0.9768 | Train Acc: 50.54% | Val Acc: 52.35% | Val F1: 0.5034 | Val AUC: 0.7193 | Time: 10.71s
# [Epoch 007/50] Train Loss: 0.9762 | Train Acc: 51.81% | Val Acc: 50.90% | Val F1: 0.4595 | Val AUC: 0.7072 | Time: 12.41s
#
#  ReduceLROnPlateau: Reducing learning rate from 0.000010 to 0.000005
# [Epoch 008/50] Train Loss: 0.9797 | Train Acc: 50.36% | Val Acc: 53.43% | Val F1: 0.5046 | Val AUC: 0.7241 | Time: 12.37s
# [Epoch 009/50] Train Loss: 0.9785 | Train Acc: 51.63% | Val Acc: 51.99% | Val F1: 0.4823 | Val AUC: 0.7111 | Time: 12.48s
# [Epoch 010/50] Train Loss: 0.9596 | Train Acc: 52.80% | Val Acc: 55.60% | Val F1: 0.5361 | Val AUC: 0.7327 | Time: 12.32s
#
# Severity_Custom_Final Model weights successfully saved to: models\severity_custom_final_cnn_pytorch.pth
# [Epoch 011/50] Train Loss: 0.9408 | Train Acc: 52.80% | Val Acc: 56.68% | Val F1: 0.5464 | Val AUC: 0.7263 | Time: 12.42s
#
# Severity_Custom_Final Model weights successfully saved to: models\severity_custom_final_cnn_pytorch.pth
# [Epoch 012/50] Train Loss: 0.9777 | Train Acc: 52.89% | Val Acc: 54.51% | Val F1: 0.5334 | Val AUC: 0.7230 | Time: 12.67s
# [Epoch 013/50] Train Loss: 0.9743 | Train Acc: 52.44% | Val Acc: 54.87% | Val F1: 0.5246 | Val AUC: 0.7301 | Time: 12.36s
# [Epoch 014/50] Train Loss: 0.9691 | Train Acc: 50.90% | Val Acc: 55.23% | Val F1: 0.5403 | Val AUC: 0.7124 | Time: 12.30s
# [Epoch 015/50] Train Loss: 0.9694 | Train Acc: 53.62% | Val Acc: 51.26% | Val F1: 0.4882 | Val AUC: 0.7069 | Time: 12.39s
#
#  ReduceLROnPlateau: Reducing learning rate from 0.000005 to 0.000003
# [Epoch 016/50] Train Loss: 0.9842 | Train Acc: 50.09% | Val Acc: 51.26% | Val F1: 0.4980 | Val AUC: 0.7096 | Time: 12.23s
# [Epoch 017/50] Train Loss: 0.9808 | Train Acc: 49.91% | Val Acc: 50.18% | Val F1: 0.4773 | Val AUC: 0.7195 | Time: 12.39s
# [Epoch 018/50] Train Loss: 0.9696 | Train Acc: 52.53% | Val Acc: 54.15% | Val F1: 0.5201 | Val AUC: 0.7203 | Time: 13.02s
# [Epoch 019/50] Train Loss: 0.9631 | Train Acc: 51.81% | Val Acc: 52.71% | Val F1: 0.5067 | Val AUC: 0.7215 | Time: 11.49s
#
# ! EARLY STOPPING triggered at epoch 19. Validation F1 score has not improved for 8 epochs.
#
# == Training Done ==
#
# Final: Loaded best model weights (F1: 0.5464) from models\severity_custom_final_cnn_pytorch.pth
# C:\Users\USER\AppData\Local\Temp\ipykernel_35216\1133255913.py:177: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_save_path))

# %%
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd

def smooth_data(data, window=3):
    # Convert list to pandas Series, apply rolling mean, and convert back to list
    return pd.Series(data).rolling(window=window, min_periods=1).mean().tolist()

epochs_run = range(1, len(severity_losses) + 1)

smooth_train_acc = smooth_data(train_accuracies)
smooth_val_acc = smooth_data(severity_accuracies)
smooth_train_loss = smooth_data(severity_losses)
smooth_val_loss = smooth_data(val_losses)
smooth_f1 = smooth_data(severity_f1_score)

# --- Visualization For Model A (2x2 Layout) ---
plt.figure(figsize=(18, 6)) # Adjusted for a 3-plot layout

# 1. ACCURACY PLOT: Training vs. Validation
plt.subplot(1, 2, 1) 
plt.plot(epochs_run, smooth_train_acc, label='Training Accuracy', color='green', marker='o', markersize=3)
plt.plot(epochs_run, smooth_val_acc, label='Validation Accuracy', color='orange', marker='o', markersize=3)
plt.title('Model A: Accuracy History')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.grid(True)
plt.legend()

# 2. LOSS PLOT: Training vs. Validation
plt.subplot(1, 2, 2) 
plt.plot(epochs_run, smooth_train_loss, label='Training Loss', color='purple', marker='^', markersize=3)
plt.plot(epochs_run, smooth_val_loss, label='Validation Loss', color='blue', marker='x', markersize=3) 
plt.title('Model A: Loss History')
plt.xlabel('Epoch')
plt.ylabel('Loss (CrossEntropy)')
plt.grid(True)
plt.legend()

plt.tight_layout() # Adjusts plots to fit nicely
plt.show() # Display the final combined figure

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

current_classes = ACCIDENT_CLASSES
visual_order = ["minor", "intermediate", "major"] 

try:
    mapping_indices = [current_classes.index(name) for name in visual_order]
except ValueError as e:
    print(f"Error: One of the classes in visual_order is not found in ACCIDENT_CLASSES. Check class names: {e}")
    mapping_indices = list(range(len(ACCIDENT_CLASSES)))
    visual_order = ACCIDENT_CLASSES

severity_cm_reordered = severity_cm[mapping_indices, :][:, mapping_indices]

fig, axes = plt.subplots(figsize=(6, 5))

# --- Model B Heatmap ---
sns.heatmap(severity_cm_reordered, annot=True, fmt='d', cmap='Blues',xticklabels=visual_order, yticklabels=visual_order, cbar=False, ax=axes)
axes.set_title("Model B: Severity Classifier (Minor, Intermediate, Major)")
axes.set_ylabel("Actual Label")
axes.set_xlabel("Predicted Label")

plt.tight_layout()
plt.show()

# %%
# Classification Report
from tabulate import tabulate
from sklearn.metrics import classification_report

# Model B
print("\n=== Classification Report: Model B (Severity Classifier) ===\n")
severity_target_names=['Minor','Intermediate','Major']
severity_report=classification_report(severity_labels,severity_predictions,target_names=ACCIDENT_CLASSES, output_dict=True, zero_division=0)
severity_rows = []
for label, metrics in severity_report.items():
    if isinstance(metrics, dict): 
        severity_rows.append([label,
                     metrics['precision'],
                     metrics['recall'],
                     metrics['f1-score'],
                     metrics['support']])
    else: 
        severity_rows.append([label, metrics, '', '', ''])
print(tabulate(severity_rows,
               headers=['Class', 'Precision', 'Recall', 'F1-Score', 'Support'],
               tablefmt='grid'))
# Out:
# === Classification Report: Model B (Severity Classifier) ===
#
# +--------------+-------------+---------------------+---------------------+-----------+
# | Class        |   Precision | Recall              | F1-Score            | Support   |
# +==============+=============+=====================+=====================+===========+
# | intermediate |    0.446429 | 0.26881720430107525 | 0.33557046979865773 | 93.0      |
# +--------------+-------------+---------------------+---------------------+-----------+
# | major        |    0.589744 | 0.7340425531914894  | 0.6540284360189573  | 94.0      |
# +--------------+-------------+---------------------+---------------------+-----------+
# | minor        |    0.605769 | 0.7                 | 0.6494845360824743  | 90.0      |
# +--------------+-------------+---------------------+---------------------+-----------+
# | accuracy     |    0.566787 |                     |                     |           |
# +--------------+-------------+---------------------+---------------------+-----------+
# | macro avg    |    0.547314 | 0.5676199191641882  | 0.5463611473000297  | 277.0     |
# +--------------+-------------+---------------------+---------------------+-----------+
# | weighted avg |    0.546834 | 0.5667870036101083  | 0.5456329780667143  | 277.0     |
# +--------------+-------------+---------------------+---------------------+-----------+

# %%
# AUC Curve
from sklearn.metrics import roc_curve, auc

def plot_multiclass_roc(y_true, y_scores, class_names):
    num_classes = len(class_names)
    y_true_bin = label_binarize(y_true, classes=range(num_classes)) 

    fpr = dict()
    tpr = dict()
    roc_auc = dict()

    for i in range(num_classes):
        fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], y_scores[:, i]) 
        roc_auc[i] = auc(fpr[i], tpr[i])

    all_fpr = np.unique(np.concatenate([fpr[i] for i in range(num_classes)]))
    mean_tpr = np.zeros_like(all_fpr)
    for i in range(num_classes):
        mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])
    mean_tpr /= num_classes
    macro_roc_auc = auc(all_fpr, mean_tpr)

    plt.figure(figsize=(8, 8))
    colors = ['blue', 'red', 'green', 'purple', 'brown'][:num_classes] 

    for i, color in zip(range(num_classes), colors):
        plt.plot(fpr[i], tpr[i], color=color, lw=2,
                 label=f'Class {class_names[i]} (AUC = {roc_auc[i]:.4f})')

    plt.plot(all_fpr, mean_tpr,
             label=f'Macro-average (AUC = {macro_roc_auc:.4f})',
             color='black', linestyle=':', linewidth=4)

    plt.plot([0, 1], [0, 1], 'k--', lw=2)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate (FPR)')
    plt.ylabel('True Positive Rate (TPR) / Recall')
    plt.title('ROC Curves: Severity Classifier (One-vs-Rest)')
    plt.legend(loc="lower right")
    plt.show()
    plt.close()

# Plot Severity Classifier ROC Curves (Multi-class OvR)
plot_multiclass_roc(
    y_true=np.array(severity_labels), 
    y_scores=severity_auc, 
    class_names=ACCIDENT_CLASSES
)

# %%
import random

model_path = "models/severity_custom_final_cnn_pytorch.pth" 
model = CNNModel(SEVERITY_NUM_CLASSES) 
model.load_state_dict(torch.load(model_path, map_location=device))
model.to(device)
model.eval() 

images, labels = next(iter(severity_val_loader)) 
images = images.to(device)
with torch.no_grad():
    outputs = model(images)
    _, predicted = torch.max(outputs.data, 1)

true_ids = labels.cpu().numpy()
pred_ids = predicted.cpu().numpy()

error_indices = np.where(pred_ids != true_ids)[0] 

PLOT_COUNT = 12
if len(error_indices) > PLOT_COUNT:
    plot_indices = random.sample(list(error_indices), PLOT_COUNT)
else:
    plot_indices = error_indices

plt.figure(figsize=(12, 9))
if len(plot_indices) == 0:
    print("No misclassified images found in this batch!")
else:
    for i, idx in enumerate(plot_indices):
        ax = plt.subplot(3, 4, i + 1)
        
        img = images[idx].cpu().numpy().transpose((1, 2, 0)) 
        
        
        true_label = ACCIDENT_CLASSES[true_ids[idx]] 
        pred_label = ACCIDENT_CLASSES[pred_ids[idx]]
        color = "red" 
        
        plt.imshow(img)
        plt.title(f"Pred: {pred_label}\nTrue: {true_label}", color=color, fontsize=9)
        plt.axis("off")

plt.tight_layout()
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_35216\454615091.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=device))
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.854995..2.233125].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.854995..0.9566192].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.854995..2.001838].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.854995..2.233125].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.854995..2.1533434].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.854995..2.233125].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.4598278..1.7703916].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.7443482..2.089518].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.854995..1.6267847].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.5862813..0.7810997].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.854995..2.233125].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.854995..2.0256927].
